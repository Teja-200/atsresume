# %% [markdown]
# <a href="https://colab.research.google.com/github/Teja-200/atsresume/blob/main/ATS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.1 MB/s eta 0:00:00
# ...

# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
    """
    Extracts text from all pages of a PDF file.
    """
    extracted_text = ""

    with open(pdf_path, "rb") as file:
        reader = PyPDF2.PdfReader(file)

        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:
                extracted_text += page_text

    return extracted_text

# %%
pdf_path = "/content/Teja_resumw (1).pdf"
text = extract_text_from_pdf(pdf_path)

print(text)
# Out:
#
#        Dwarampudi Teja Siva Sai Swaroop Reddy
#  I +91 9030048907  • # swaroopreddy995144@gmail.com  • ð Teja -Dwarampudi
# Executive Summary
#
# Motivated B.Tech IT undergraduate with str ong expertise in full -stack web development and UI/UX design, experienced
# in building scalable applications using modern technologies.
# Proven ability to design intuitive user experiences and develop intelligent, real -world solutions through academic and
# project -based work.
#
# Education
#
# Vishnu Institute of Technology  Bhimavaram, Andhra Pradesh
# Bachelor of Engineering in IT
#  CGPA: 8.89*  2023–2027
#
# Aditya Junior College  Mandapeta, East Godavari,
# Andhra Pradesh
# Intermediate (MPC)
# Percentage: 97%  2021–2023
#
# Projects
#
# Mentor -Connect – Student -Mentor Collaboration Platform
# • Developed a full -stack web application that connects students with mentors for various courses, enabling personalized guidance
# and structured learning.
# ...

# %%
from google import genai
client = genai.Client(api_key='AIzaSyAnFpucHrr4mBFS97HBjrp3ExM9PuiGG1g')

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=f'here is the context:{text} question: give rate about my resume 100'
)

print(response.text)
# Out:
# This is an **excellent resume**, especially for an undergraduate! It's well-structured, clear, and highlights your strengths effectively.
#
# Here's a breakdown and a rating:
#
# ---
#
# **Rating: 94/100**
#
# ---
#
# **Strengths:**
#
# 1.  **Strong Executive Summary:** It's concise, impactful, and immediately communicates your value proposition, expertise, and aspirations.
# 2.  **Well-Presented Education:** Clear details, good GPA/percentage, and relevant academic background.
# 3.  **Impressive Projects:**
#     *   **Diversity:** You showcase both full-stack development (Mentor-Connect, Mobile Location Bot) and strong UI/UX design skills (Zomato UI Clone). This broadens your appeal significantly.
#     *   **Detail-Oriented Descriptions:** Each project uses strong action verbs and clearly explains the technologies used, the features implemented, and the impact/purpose.
# ...

# %%
def resume_parser(input):
  prompt=f"""
  your resume parser
  Extract:
  -Executive Summary
  -Skills
  -Education
  -Tools & Techonolgies
  -Experience Summary

  Resume:
  {input}
  return in bullet points
  """
  response = client.models.generate_content(
          model = "gemini-2.5-flash",
          contents = prompt
  )
  return response.text

tejas = resume_parser(text)
print(tejas)
# Out:
# Here's the extracted information from the resume:
#
# **-Executive Summary**
# *   Motivated B.Tech IT undergraduate with strong expertise in full-stack web development and UI/UX design, experienced in building scalable applications using modern technologies.
# *   Proven ability to design intuitive user experiences and develop intelligent, real-world solutions through academic and project-based work.
#
# **-Skills**
# *   **Languages:** Python, JavaScript, HTML, CSS, SQL, Java
# *   **Web Development:** Node.js, Firebase, MongoDB, REST APIs, React, Express.js
#
# **-Education**
# *   **Vishnu Institute of Technology:** Bachelor of Engineering in IT, CGPA: 8.89*, 2023–2027, Bhimavaram, Andhra Pradesh
# *   **Aditya Junior College:** Intermediate (MPC), Percentage: 97%, 2021–2023, Mandapeta, East Godavari, Andhra Pradesh
#
# **-Tools & Technologies**
# *   Git
# *   GitHub
# *   VS Code
# *   Telegram Bot API
#
# **-Experience Summary**
# ...

# %%
def jobDescription(output):
  prompt=f"""
  your jobDescription parser
  Extract:
   -Skills
   -Responsebilities
   -Qualifications

   Job Description:
   {output}
  return in bullet points
  """

  response = client.models.generate_content(
      model = "gemini-2.5-flash",
      contents = prompt
  )
  print(response.text)
  return response.text

 # Resume parsing
teja = jobDescription(text)
print("===== PARSED RESUME =====")
print(teja)
# Out:
# Here's the extracted information from the provided Job Description (interpreted as a Resume for this parsing task):
#
# ### Skills
#
# *   **Languages:** Python, JavaScript, HTML, CSS, SQL, Java
# *   **Web Development:** Node.js, Firebase, MongoDB, REST APIs, React, Express.js
# *   **Tools & Platforms:** Git, GitHub, VS Code, Telegram Bot API, Figma
# *   Full-stack Web Development
# *   UI/UX Design
# *   Application Architecture & Scalability
# *   User Experience Design (Intuitive UI)
# *   Problem Solving (Developing intelligent solutions)
# *   Database Management (MongoDB)
# *   Prototyping & Wireframing
# *   Responsive Design
# *   API Integration
# *   Backend Deployment
# *   Role-based Authentication Implementation
# *   Scheduling Feature Development
# *   Intelligent Matching Logic Development
#
# ### Responsibilities (Interpreted as Key Achievements/Experience from Projects)
#
# *   **Full-stack Web Development:**
# ...

# %%
def ats_match(parsed_resume, parsed_jd):
    prompt = f"""
You are an Applicant Tracking System.

Compare the resume and job description.

Resume:
{parsed_resume}

Job Description:
{parsed_jd}

Provide:
1. Match percentage (0-100)
2. Matching skills
3. Missing skills
4. Strengths
5. Improvement suggestions
"""
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text

# %%
ats_result = ats_match(tejas, teja)

print("===== ATS MATCH RESULT =====")
print(ats_result)
# Out:
# ===== ATS MATCH RESULT =====
# As an Applicant Tracking System, I have analyzed the provided resume against the job description (representing an ideal candidate profile).
#
# ---
#
# ### 1. Match Percentage
#
# **96%**
#
# ---
#
# ### 2. Matching Skills
#
# The candidate's resume shows strong alignment with the job description's requirements.
#
# *   **Languages:** Python, JavaScript, HTML, CSS, SQL, Java
# *   **Web Development:** Node.js, Firebase, MongoDB, REST APIs, React, Express.js
# *   **Tools & Platforms:** Git, GitHub, VS Code, Telegram Bot API, Figma
# *   **Conceptual & Domain Skills:**
#     *   Full-stack Web Development
#     *   UI/UX Design
#     *   Application Architecture & Scalability
#     *   User Experience Design (Intuitive UI)
#     *   Problem Solving (Developing intelligent solutions)
#     *   Database Management (MongoDB)
#     *   Prototyping & Wireframing
#     *   Responsive Design
#     *   API Integration
#     *   Backend Deployment
# ...
